# %%
import pandas as pd

data = pd.read_csv("Reviews.csv")
data
data.shape[0]
# Out:
# 393568

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    punctuation_free = ""
    
    for i in text:
        if i not in string.punctuation:
            punctuation_free += i
    
    return punctuation_free

# %%
data['clean_punctuation']= data['Text'].apply(remove_punctuation)
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
# [393568 rows x 2 columns]

# %%
data['clean_lower']= data['clean_punctuation'].str.lower()
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
# [393568 rows x 3 columns]

# %%
import re

def remove_numbers(text):
    return re.sub("[\d-]",'',text)

data['clean_number'] = data['clean_lower'].apply(remove_numbers)
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                              clean_number
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give  of thos...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
# [393568 rows x 4 columns]

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

data['token_data']= data['clean_number'].apply(word_tokenize)
data
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ikmalkamil/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                              clean_number  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give  of thos...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                                token_data
# 0       [i, have, bought, several, of, the, vitality, ...
# 1       [product, arrived, labeled, as, jumbo, salted,...
# 2       [this, is, a, confection, that, has, been, aro...
# 3       [if, you, are, looking, for, the, secret, ingr...
# 4       [great, taffy, at, a, great, price, there, was...
# ...                                                   ...
# 393563  [great, for, sesame, chickenthis, is, a, good,...
# 393564  [im, disappointed, with, the, flavor, the, cho...
# 393565  [these, stars, are, small, so, you, can, give,...
# 393566  [these, are, the, best, treats, for, training,...
# 393567  [i, am, very, satisfied, product, is, as, adve...
#
# [393568 rows x 5 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ikmalkamil/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def remove_stopwords(text):
    output = []
    for i in text:
        if i not in stopwords:
            output.append(i)
    return output

# %%
data['clean_xstopwords'] = data['token_data'].apply(remove_stopwords)
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                              clean_number  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give  of thos...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                                token_data  \
# 0       [i, have, bought, several, of, the, vitality, ...
# 1       [product, arrived, labeled, as, jumbo, salted,...
# 2       [this, is, a, confection, that, has, been, aro...
# 3       [if, you, are, looking, for, the, secret, ingr...
# 4       [great, taffy, at, a, great, price, there, was...
# ...                                                   ...
# 393563  [great, for, sesame, chickenthis, is, a, good,...
# 393564  [im, disappointed, with, the, flavor, the, cho...
# 393565  [these, stars, are, small, so, you, can, give,...
# 393566  [these, are, the, best, treats, for, training,...
# 393567  [i, am, very, satisfied, product, is, as, adve...
#
#                                          clean_xstopwords
# 0       [bought, several, vitality, canned, dog, food,...
# 1       [product, arrived, labeled, jumbo, salted, pea...
# 2       [confection, around, centuries, light, pillowy...
# 3       [looking, secret, ingredient, robitussin, beli...
# 4       [great, taffy, great, price, wide, assortment,...
# ...                                                   ...
# 393563  [great, sesame, chickenthis, good, better, res...
# 393564  [im, disappointed, flavor, chocolate, notes, e...
# 393565  [stars, small, give, one, training, session, t...
# 393566  [best, treats, training, rewarding, dog, good,...
# 393567  [satisfied, product, advertised, use, cereal, ...
#
# [393568 rows x 6 columns]

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter_stemmer = PorterStemmer()

# %%
def stemming(text) :
    stem_text = []
    for word in text:
        stemmed_word = porter_stemmer.stem(word)
        stem_text.append(stemmed_word)
    return stem_text

# %%
data['clean_stemmed'] = data['clean_xstopwords'].apply(stemming)
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                              clean_number  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give  of thos...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                                token_data  \
# 0       [i, have, bought, several, of, the, vitality, ...
# 1       [product, arrived, labeled, as, jumbo, salted,...
# 2       [this, is, a, confection, that, has, been, aro...
# 3       [if, you, are, looking, for, the, secret, ingr...
# 4       [great, taffy, at, a, great, price, there, was...
# ...                                                   ...
# 393563  [great, for, sesame, chickenthis, is, a, good,...
# 393564  [im, disappointed, with, the, flavor, the, cho...
# 393565  [these, stars, are, small, so, you, can, give,...
# 393566  [these, are, the, best, treats, for, training,...
# 393567  [i, am, very, satisfied, product, is, as, adve...
#
#                                          clean_xstopwords  \
# 0       [bought, several, vitality, canned, dog, food,...
# 1       [product, arrived, labeled, jumbo, salted, pea...
# 2       [confection, around, centuries, light, pillowy...
# 3       [looking, secret, ingredient, robitussin, beli...
# 4       [great, taffy, great, price, wide, assortment,...
# ...                                                   ...
# 393563  [great, sesame, chickenthis, good, better, res...
# 393564  [im, disappointed, flavor, chocolate, notes, e...
# 393565  [stars, small, give, one, training, session, t...
# 393566  [best, treats, training, rewarding, dog, good,...
# 393567  [satisfied, product, advertised, use, cereal, ...
#
#                                             clean_stemmed
# 0       [bought, sever, vital, can, dog, food, product...
# 1       [product, arriv, label, jumbo, salt, peanutsth...
# 2       [confect, around, centuri, light, pillowi, cit...
# 3       [look, secret, ingredi, robitussin, believ, fo...
# 4       [great, taffi, great, price, wide, assort, yum...
# ...                                                   ...
# 393563  [great, sesam, chickenthi, good, better, restu...
# 393564  [im, disappoint, flavor, chocol, note, especi,...
# 393565  [star, small, give, one, train, session, tri, ...
# 393566  [best, treat, train, reward, dog, good, groom,...
# 393567  [satisfi, product, advertis, use, cereal, raw,...
#
# [393568 rows x 7 columns]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ikmalkamil/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def lemmatizer(text):
    lemm_text = []
    for word in text:
        lemmatized_word = wordnet_lemmatizer.lemmatize(word)
        lemm_text.append(lemmatized_word)
    return lemm_text

# %%
data['clean_lemmatized1']=data['clean_xstopwords'].apply(lemmatizer)

# %%
data['clean_lemmatized2']=data['clean_stemmed'].apply(lemmatizer)
data
# Out:
#                                                      Text  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 393563  Great for sesame chicken..this is a good if no...
# 393564  I'm disappointed with the flavor. The chocolat...
# 393565  These stars are small, so you can give 10-15 o...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied ,product is as advertised,...
#
#                                         clean_punctuation  \
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price  There was a wide...
# ...                                                   ...
# 393563  Great for sesame chickenthis is a good if not ...
# 393564  Im disappointed with the flavor The chocolate ...
# 393565  These stars are small so you can give 1015 of ...
# 393566  These are the BEST treats for training and rew...
# 393567  I am very satisfied product is as advertised I...
#
#                                               clean_lower  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give 1015 of ...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                              clean_number  \
# 0       i have bought several of the vitality canned d...
# 1       product arrived labeled as jumbo salted peanut...
# 2       this is a confection that has been around a fe...
# 3       if you are looking for the secret ingredient i...
# 4       great taffy at a great price  there was a wide...
# ...                                                   ...
# 393563  great for sesame chickenthis is a good if not ...
# 393564  im disappointed with the flavor the chocolate ...
# 393565  these stars are small so you can give  of thos...
# 393566  these are the best treats for training and rew...
# 393567  i am very satisfied product is as advertised i...
#
#                                                token_data  \
# 0       [i, have, bought, several, of, the, vitality, ...
# 1       [product, arrived, labeled, as, jumbo, salted,...
# 2       [this, is, a, confection, that, has, been, aro...
# 3       [if, you, are, looking, for, the, secret, ingr...
# 4       [great, taffy, at, a, great, price, there, was...
# ...                                                   ...
# 393563  [great, for, sesame, chickenthis, is, a, good,...
# 393564  [im, disappointed, with, the, flavor, the, cho...
# 393565  [these, stars, are, small, so, you, can, give,...
# 393566  [these, are, the, best, treats, for, training,...
# 393567  [i, am, very, satisfied, product, is, as, adve...
#
#                                          clean_xstopwords  \
# 0       [bought, several, vitality, canned, dog, food,...
# 1       [product, arrived, labeled, jumbo, salted, pea...
# 2       [confection, around, centuries, light, pillowy...
# 3       [looking, secret, ingredient, robitussin, beli...
# 4       [great, taffy, great, price, wide, assortment,...
# ...                                                   ...
# 393563  [great, sesame, chickenthis, good, better, res...
# 393564  [im, disappointed, flavor, chocolate, notes, e...
# 393565  [stars, small, give, one, training, session, t...
# 393566  [best, treats, training, rewarding, dog, good,...
# 393567  [satisfied, product, advertised, use, cereal, ...
#
#                                             clean_stemmed  \
# 0       [bought, sever, vital, can, dog, food, product...
# 1       [product, arriv, label, jumbo, salt, peanutsth...
# 2       [confect, around, centuri, light, pillowi, cit...
# 3       [look, secret, ingredi, robitussin, believ, fo...
# 4       [great, taffi, great, price, wide, assort, yum...
# ...                                                   ...
# 393563  [great, sesam, chickenthi, good, better, restu...
# 393564  [im, disappoint, flavor, chocol, note, especi,...
# 393565  [star, small, give, one, train, session, tri, ...
# 393566  [best, treat, train, reward, dog, good, groom,...
# 393567  [satisfi, product, advertis, use, cereal, raw,...
#
#                                         clean_lemmatized1  \
# 0       [bought, several, vitality, canned, dog, food,...
# 1       [product, arrived, labeled, jumbo, salted, pea...
# 2       [confection, around, century, light, pillowy, ...
# 3       [looking, secret, ingredient, robitussin, beli...
# 4       [great, taffy, great, price, wide, assortment,...
# ...                                                   ...
# 393563  [great, sesame, chickenthis, good, better, res...
# 393564  [im, disappointed, flavor, chocolate, note, es...
# 393565  [star, small, give, one, training, session, tr...
# 393566  [best, treat, training, rewarding, dog, good, ...
# 393567  [satisfied, product, advertised, use, cereal, ...
#
#                                         clean_lemmatized2
# 0       [bought, sever, vital, can, dog, food, product...
# 1       [product, arriv, label, jumbo, salt, peanutsth...
# 2       [confect, around, centuri, light, pillowi, cit...
# 3       [look, secret, ingredi, robitussin, believ, fo...
# 4       [great, taffi, great, price, wide, assort, yum...
# ...                                                   ...
# 393563  [great, sesam, chickenthi, good, better, restu...
# 393564  [im, disappoint, flavor, chocol, note, especi,...
# 393565  [star, small, give, one, train, session, tri, ...
# 393566  [best, treat, train, reward, dog, good, groom,...
# 393567  [satisfi, product, advertis, use, cereal, raw,...
#
# [393568 rows x 9 columns]

# %%
data.to_csv('processed_data.csv', index=False)
